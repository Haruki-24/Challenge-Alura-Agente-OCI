# %% [markdown]
# # Proyecto: Agente de Operations & Control Industrial (OCI)

# %% [markdown]
# ## 0 - Configuracion de entorno

# %% [markdown]
# ### Instalación de depedencias

# %%
# 1. Creamos el archivo requirements.txt incluyendo el paquete faltante
requirements_content = """
faiss-cpu
google-generativeai
langchain
langchain-community
langchain-core
langchain-google-genai
langgraph
openpyxl
pandas
PyMuPDF
pypdf
python-dotenv
unstructured
langchain-experimental
langchain-huggingface
"""

with open("requirements.txt", "w") as f:
    f.write(requirements_content.strip())

print("Archivo 'requirements.txt' actualizado con langchain-huggingface.")

# 2. Instalamos de manera limpia
# !pip install -q -r requirements.txt
print("¡Entorno configurado con éxito!")
# Out:
# ✅ Archivo 'requirements.txt' actualizado con langchain-huggingface.
# 🚀 ¡Entorno configurado con éxito!

# %% [markdown]
# ### Importación de biibliotecas y conexión con LLMs

# %%
import os
from getpass import getpass
import pandas as pd
# Importaciones clave de LangChain / Google GenAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.vectorstores import FAISS

print("✅ Bibliotecas base importadas con éxito.")
# Out:
# ✅ Bibliotecas base importadas con éxito.
# /tmp/ipykernel_19395/4043027227.py:7: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS

# %%
#Recuperacion y validacion de Api key
from google.colab import userdata
GEMINI_API_KEY = userdata.get('Gemini-GC')

# %% [markdown]
# ## 1 - Extracción y carga de datos

# %%
# !pip install -q "unstructured[pdf]" # 1. Asegurar la instalación de las dependencias necesarias

# !pip show unstructured # 2. Verificación de la instalación
# Out:
# Name: unstructured
# Version: 0.23.1
# Summary: A library that prepares raw documents for downstream ML tasks.
# Home-page: https://github.com/Unstructured-IO/unstructured
# Author:
# Author-email: Unstructured Technologies <devops@unstructuredai.io>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: beautifulsoup4, charset-normalizer, emoji, filelock, filetype, html5lib, installer, langdetect, lxml, numba, numpy, psutil, python-iso639, python-magic, python-oxmsg, rapidfuzz, regex, requests, spacy, tqdm, typing-extensions, unstructured-client, wrapt
# Required-by:

# %%
# Importaciones necesarias para el cargador fusionado
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader, UnstructuredExcelLoader, TextLoader
from langchain_community.document_loaders.merge import MergedDataLoader

# Carga de los documentos desde tu ruta especificada
url_docs = '/content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs'

# 3. Definición de cargadores por tipo de archivo
# Los PDFs usan PyPDFLoader
loader_pdfs = DirectoryLoader(url_docs, glob="*.pdf", loader_cls=PyPDFLoader)

# Los Excel usan UnstructuredExcelLoader
loader_excel = DirectoryLoader(url_docs, glob="*.xlsx", loader_cls=UnstructuredExcelLoader)

# 4. Fusión de cargadores
all_loaders = MergedDataLoader(loaders=[loader_pdfs, loader_excel])

# 5. Carga final
print("⏳ Cargando documentos...")
documentos_oci = all_loaders.load()

# 6. Validación
print(f"✅ Se han cargado exitosamente {len(documentos_oci)} documentos en total.")

if len(documentos_oci) > 0:
    print(f"📄 Primer documento cargado: {documentos_oci[0].metadata.get('source', 'Desconocido')}")
# Out:
# ⏳ Cargando documentos...
# ✅ Se han cargado exitosamente 7 documentos en total.
# 📄 Primer documento cargado: /content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs/Politica_HSE_OCI.pdf

# %%
documentos_oci
# Out:
# [Document(metadata={'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-06-27T02:42:36+00:00', 'title': 'Desafío de Agente IA para Documentos - Google Gemini', 'moddate': '2026-06-27T02:42:36+00:00', 'source': '/content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs/Politica_HSE_OCI.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Política de Salud, Seguridad y Medio Ambiente (HSE) - OCI\n1. Compromiso Fundamental\nEn Operations & Control Industrial (OCI), reconocemos que la integridad de nuestro personal, la protección dela salud y el cuidado del medio ambiente son valores innegociables. Ninguna tarea operativa es tan urgente ni tanprioritaria que no pueda realizarse de manera segura y responsable. Nuestro compromiso es entregar solucionestecnológicas de vanguardia sin comprometer nunca nuestros estándares HSE.\n2. Pilares de Nuestra Gestión\nNuestra estrategia de seguridad se fundamenta en tres ejes que guían toda operación de campo:\nSeguridad Innegociable (Safety First): Implementamos sistemas de gestión de riesgos basados enestándares internacionales para identificar, evaluar y controlar peligros en todas las operaciones de pulling ymantenimiento.\nGestión Ambiental: Nos comprometemos a minimizar el impacto ambiental mediante el uso eficiente de losrecursos y una gestión rigurosa de residuos. Buscamos innovar tecnológicamente para optimizar eldesempeño energético de los activos que operamos.\nExcelencia impulsada por Datos: La seguridad no es intuitiva; es técnica. Utilizamos nuestra infraestructurade datos y monitoreo en tiempo real para anticipar riesgos y prevenir incidentes antes de que ocurran.\n3. Compromisos de OCI\nCultura Proactiva: Promovemos un entorno donde cada empleado y contratista asume la responsabilidadpersonal de su seguridad y la de sus compañeros, reportando activamente cualquier condición insegura.\nCumplimiento Normativo: Operamos bajo estricto cumplimiento de las leyes locales y regulaciones de laindustria hidrocarburífera, manteniendo siempre un marco de mejora continua.\nCapacitación y Competencia: Garantizamos que todo el personal cuente con las competencias,herramientas y equipo de protección personal (EPP) necesarios para ejecutar sus tareas de forma segura.\nEvaluación de Proveedores: Exigimos a nuestros socios y proveedores que compartan nuestros mismosestándares de HSE, integrándolos en nuestra cadena de valor.\n4. Liderazgo y Mejora Continua\nLa alta dirección de OCI asume el liderazgo en la promoción de esta política, asignando los recursos necesariospara su implementación. Evaluamos nuestro desempeño a través de auditorías periódicas e indicadores clave(KPIs), asegurando que nuestros procedimientos digitales (órdenes de trabajo, planes de intervención) siemprereflejen nuestro compromiso con la seguridad.\nEn OCI, la tecnología sirve a la seguridad.\nexpand\ntune\nchat_spark'),
#  Document(metadata={'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-06-27T02:49:20+00:00', 'title': 'Desafío de Agente IA para Documentos - Google Gemini', 'moddate': '2026-06-27T02:49:20+00:00', 'source': '/content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs/Programa_intervenciones_de_pulling.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Programa de Intervenciones - Pulling (OCI)\nObjetivo\nCronograma dinámico de intervenciones de Pulling. Este documento es la fuente de verdad para la asignación deequipos, estimación de tiempos y priorización de pozos.\nIDPozoTipo PrioridadEstado EquipoPulling Fecha Est.Inicio Cuadrilla Notas\nP-101 PCP Alta Pendiente PullingU-01 27/06/2026 CuadrillaAlpha Cambio debomba (2-5 días).Riesgo desurgencia.\nP-202 ElectrosumergibleMedia En Curso PullingU-02 26/06/2026 CuadrillaBeta Inspección desellos (2 días).\nP-303 AIB Baja ProgramadoPullingU-01 29/06/2026 CuadrillaAlpha Cambio decorreas (1-2 días).\nP-404 PCP Crítica Detenido GrúaPesada 26/06/2026 CuadrillaBeta Falla de varilla.Requiere izaje (2-5 días).\nNota 1: Los tiempos de duración estimados consideran contingencias climáticas y disponibilidad de materiales.Nota 2: Todo cambio en la prioridad debe ser validado por la jefatura antes de la salida.\nexpand\ntune\nchat_spark'),
#  Document(metadata={'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-06-27T02:43:17+00:00', 'title': 'Desafío de Agente IA para Documentos - Google Gemini', 'moddate': '2026-06-27T02:43:17+00:00', 'source': '/content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs/Mision_vision_y_valores_OCI.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='OCI: Operations & Control Industrial\nIdentidad Corporativa y Ejes Estratégicos\nDescripción General\nOperations & Control Industrial (OCI) es una empresa líder en servicios estratégicos para el sector de Oil & Gas.Nuestra organización se fundamenta en la convergencia de la excelencia operativa tradicional y la vanguardiatecnológica. En un sector caracterizado por la complejidad y el alto riesgo, OCI se destaca por implementarsoluciones de Inteligencia Artificial y arquitecturas de datos en la gestión de mantenimiento, asegurando que lascuadrillas de trabajo cuenten con información precisa, segura y en tiempo real. Actuamos como el nexotecnológico entre los activos físicos de pozo y la toma de decisiones basada en datos.\nMisión\nPotenciar la eficiencia y la seguridad en la industria del Oil & Gas mediante la integración de tecnologíasinteligentes en la coordinación de equipos y procesos operativos, transformando los datos en acciones demantenimiento críticas que maximicen la productividad y minimicen el tiempo de inactividad (NPT).\nVisión\nConvertirnos en el estándar de referencia global para la automatización y gestión inteligente de operaciones decampo, siendo reconocidos por nuestra capacidad de simplificar entornos complejos y garantizar la continuidadoperativa bajo los más altos estándares de seguridad.\nValores Fundamentales\n1. Seguridad Innegociable (Safety First): La integridad humana y operativa está por encima de cualquierobjetivo de producción. Todo procedimiento digital debe reflejar nuestra cultura HSE (Health, Safety, andEnvironment).\n2. Eficiencia impulsada por Datos: Creemos en la precisión. La toma de decisiones no se basa ensuposiciones, sino en el análisis objetivo de la información técnica disponible.\n3. Innovación Aplicada: No implementamos tecnología por moda, sino por propósito. Cada herramienta quedesarrollamos debe resolver un problema real de campo.\n4. Resiliencia Operativa: Somos expertos en coordinar equipos en entornos de alta demanda, asegurandorespuestas ágiles ante imprevistos técnicos.\nCompromiso OCI\nEn OCI, no solo operamos pozos; gestionamos el conocimiento. Nuestra promesa a nuestros colaboradores esproporcionar claridad en el caos, transformando manuales, reportes y órdenes de trabajo en un activo inteligenteaccesible para todo el equipo.\nexpand\ntune\nchat_spark'),
#  Document(metadata={'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-06-27T02:39:07+00:00', 'title': 'Desafío de Agente IA para Documentos - Google Gemini', 'moddate': '2026-06-27T02:39:07+00:00', 'source': '/content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs/Procedimiento_y_protocolos_HSE_OCI.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Procedimiento de Trabajo en Campo y Protocolos de EPP - OCI\n1. Planificación y Logística\nProgramación: El supervisor debe programar las tareas operativas, idealmente, el día anterior a la ejecución.\nSolicitud y Verificación: Las cuadrillas son responsables de solicitar las tareas, verificar la disponibilidad demateriales y asegurar el cumplimiento estricto del protocolo de EPP según la naturaleza del trabajo.\nVerificación Pre-salida: Antes de abandonar la base, es obligatorio realizar una inspección final del equipo yEPP de todo el personal.\n2. Protocolo de EPP (Equipo de Protección Personal)\nEl uso de EPP es innegociable. Todo personal debe contar con:\nBásico: Calzado de seguridad, mameluco (overol), gafas de seguridad, protector auditivo y casco.\nGuantes (según tarea): Eléctricos, de vaqueta o de nitrilo.\nContexto de Campo: Siempre asegurar un par de guantes extra y gafas oscuras (protección UV).\nAntecedentes : Si el pozo presenta riesgo de sulfuro de hidrógeno, es obligatorio llevar 2 equipos de\ndetección por cuadrilla.\nPulling: Además de lo básico, es obligatorio el uso de mameluco impermeable de cuerpo completo (tipopintores) para protección ante posibles surgencias.\n3. Procedimientos de Izaje\nPara toda tarea de izaje (levantamiento de equipos para traslado a taller o movimiento pesado):\nPersonal mínimo: La tarea debe realizarse con al menos 2 personas.\nSeguridad del entorno: Señalamiento obligatorio del área de maniobras mediante conos.\nEquipamiento: Uso estricto de elementos certificados: soga, grilletes, eslingas y cadenas.\n4. Herramientas y Equipamiento Técnico\nEl personal debe portar la caja de herramientas estándar, complementada con herramientas específicas según elárea:\nA. Terminación de Pozos\nTorquímetro (debidamente calibrado).\nB. Mantenimiento Eléctrico\nCaja de herramientas eléctricas que debe incluir:\nInstrumentos de medición: Pinza amperométrica y tester (multímetro).\nHerramienta manual: Pinzas, alicate, destornilladores (diferentes medidas y modelos).\nMateriales: Rollo de cable.\nEn OCI, la preparación es la primera capa de seguridad.\nH S2\nexpand\ntune\nchat_spark'),
#  Document(metadata={'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-06-27T02:44:00+00:00', 'title': 'Desafío de Agente IA para Documentos - Google Gemini', 'moddate': '2026-06-27T02:44:00+00:00', 'source': '/content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs/Procedimiento_supervisor_de_campo_OCI.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Procedimiento Operativo: Coordinación de Tareas y Prioridades -OCI\n1. Objetivo\nEstablecer los criterios claros de toma de decisiones para la asignación de recursos y la gestión de prioridadesentre las cuadrillas de Pulling y Mantenimiento, garantizando la continuidad operativa sin comprometer laseguridad.\n2. Definiciones de Prioridad\nLa criticidad de una tarea se define según su impacto:\nNivel 1 (Crítico/Seguridad): Tareas que mitigan riesgos directos a la integridad física de las personas, elmedio ambiente o la operatividad crítica de los activos.\nNivel 2 (Operativo/Programado): Tareas de mantenimiento preventivo o intervenciones de pulling segúncronograma.\n3. Reglas de Priorización y Asignación\nLa toma de decisiones seguirá el siguiente flujo lógico:\n1. Seguridad Innegociable: Ninguna tarea de Pulling o Mantenimiento podrá ejecutarse si viola los estándaresHSE de OCI. La seguridad de las personas y el medio ambiente siempre tendrá la prioridad absoluta.\n2. Conflicto de Recursos:\nSi una cuadrilla de Pulling requiere personal adicional para una intervención, se solicitará apoyo a lacuadrilla de Mantenimiento.\nLa cuadrilla de Mantenimiento cederá el personal al Pulling solo si sus tareas actuales son de Nivel 2 (Nocríticas).\nSi la tarea de Mantenimiento es de Nivel 1 (Crítica), la solicitud de apoyo para Pulling será rechazada opostergada, y el mantenimiento tendrá prioridad absoluta.\n3. Cronograma Dinámico: El cronograma de Pulling está sujeto a cambios basados en la urgencia técnica, perodichos cambios deben ser validados contra la disponibilidad de recursos y la evaluación de riesgos.\n4. Matriz de Decisión para el Agente (Soporte Operativo)\nSituación Acción Prioridad\nMantenimiento crítico (Riesgo ambiental/seguridad) Priorizar Mantenimiento Máxima\nMantenimiento no crítico + Pulling urgente Apoyar Pulling con Mantenimiento Media\nFalta de personal en ambos Priorizar Seguridad/Riesgo Crítico Según Análisis HSE\n5. Responsabilidad de la Coordinación\nLa jefatura de operaciones es responsable de asegurar que el intercambio de recursos entre áreas estédocumentado en el sistema digital de gestión de OCI, asegurando que el cruce de información siempre refleje elestado real de los pozos y la seguridad del equipo.\nEn OCI, la eficiencia es coordinada, pero la seguridad es absoluta.\nexpand\ntune\nchat_spark'),
#  Document(metadata={'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-06-27T02:48:48+00:00', 'title': 'Desafío de Agente IA para Documentos - Google Gemini', 'moddate': '2026-06-27T02:48:48+00:00', 'source': '/content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs/Programa_mantenimiento.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Programa de Mantenimiento - Operaciones & Control Industrial(OCI)\nObjetivo\nGestión de tareas de mantenimiento. Cruce operativo con el Programa de Pulling para optimización de recursos.\nID PozoTipo Tarea Específica Fecha Prog. CuadrillaUrgenciaHerramientas\nE-501 ElectroChequeo tablero 26/06/2026 Mant. 1 Alta Pinza, tester.\nM-707 PCP Retiro cabezal (Pre-Pulling) 27/06/2026 Mant. 2 Media Torquímetro, llaves.\nE-808 AIB Reemplazo controlador 28/06/2026 Mant. 1 Baja Caja eléctrica.\nM-909 ElectroMedición aislamiento 26/06/2026 Mant. 2 Media Megóhmetro.\nNota: Para pozos PCP, el retiro del equipo de superficie debe coordinarse estrictamente 24 horas antes de lallegada del equipo de Pulling.Importante: Todo personal debe verificar la lista de EPP antes de salir a base.\nexpand\ntune\nchat_spark'),
#  Document(metadata={'producer': 'Skia/PDF m149', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36', 'creationdate': '2026-06-27T02:48:04+00:00', 'title': 'Desafío de Agente IA para Documentos - Google Gemini', 'moddate': '2026-06-27T02:48:04+00:00', 'source': '/content/drive/MyDrive/Colab Notebooks/Challenge Agente OCI/docs/Inventario_herramientas_EPP.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Inventario de Recursos - OCI (Operations & Control Industrial)\nObjetivo\nGestión de stock de EPP, herramientas y materiales. Este archivo permite al agente verificar disponibilidad antesde confirmar una tarea.\nNota: Si el Stock Actual es menor o igual al Stock Mínimo, el sistema debe alertar al supervisor para gestión decompra o traslado desde otra base.\nÍtem Categoría Stock Actual Stock Mínimo Unidad\nMameluco Impermeable (Pintor) EPP 15 20 Unidades\nGuantes de Vaqueta EPP 50 100 Pares\nGuantes de Nitrilo EPP 80 100 Pares\nGafas de Seguridad (Claras) EPP 120 50 Unidades\nGafas Oscuras (UV) EPP 45 40 Unidades\nDetector H2S (Calibrado) EPP 10 8 Unidades\nTorquímetro Herramientas 4 2 Unidades\nPinza Amperométrica Herramientas 6 4 Unidades\nTester (Multímetro) Herramientas 8 4 Unidades\nCable (Rollo 50m) Material 2 5 Rollos\nConos de señalización Seguridad 12 10 Unidades\nEslingas de Izaje Seguridad 6 4 Unidades\nReglas de Negocio para el Agente\n1. Verificación Proactiva: Antes de confirmar una tarea (ej. retiro de equipo con torquímetro), el agente debeverificar si el ítem tiene stock suficiente.\n2. Alertas de Compra: Si el stock < mínimo, el agente debe responder: "Alerta: Stock crítico de\n. Se recomienda generar orden de compra antes de programar la tarea."\n3. Escalabilidad: Este inventario debe actualizarse semanalmente por el almacén para que el agente tengavisibilidad real.\nEn OCI, no programamos lo que no podemos ejecutar.\ntemIˊ\nexpand\ntune\nchat_spark')]

# %% [markdown]
# ### Extracción PDF

# %% [markdown]
# ### Extracción csv y Excel

# %% [markdown]
# ## 2 - Fragmentación

# %%
# Splitter de texto para PDFs (ej. RecursiveCharacterTextSplitter)
# Estrategia de parseo para filas de CSV/Excel (guardando ID_Pozo como metadato)

from langchain_text_splitters import RecursiveCharacterTextSplitter

# Configuramos el splitter para documentos técnicos
# chunk_size=500: Un buen tamaño para que el LLM tenga contexto sin perderse
# chunk_overlap=50: Mantiene una pequeña continuidad entre bloques
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    separators=["\n\n", "\n", ".", " ", ""]
)

# Ahora dividimos los documentos
documentos_fragmentados = text_splitter.split_documents(documentos_oci)

# Verificamos
print(f"✅ Documentos originales: {len(documentos_oci)}")
print(f"✅ Fragmentos (chunks) resultantes: {len(documentos_fragmentados)}")

# Inspección rápida del primer fragmento
print("\n--- Ejemplo de fragmento ---")
print(documentos_fragmentados[0].page_content)
# Out:
# ✅ Documentos originales: 7
# ✅ Fragmentos (chunks) resultantes: 34
#
# --- Ejemplo de fragmento ---
# Política de Salud, Seguridad y Medio Ambiente (HSE) - OCI
# 1. Compromiso Fundamental
# En Operations & Control Industrial (OCI), reconocemos que la integridad de nuestro personal, la protección dela salud y el cuidado del medio ambiente son valores innegociables. Ninguna tarea operativa es tan urgente ni tanprioritaria que no pueda realizarse de manera segura y responsable. Nuestro compromiso es entregar solucionestecnológicas de vanguardia sin comprometer nunca nuestros estándares HSE.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Usamos el encoder de tiktoken para contar tokens reales
# Asegúrate de tener instalado: pip install tiktoken
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=500,    # Ahora esto son 500 TOKENS, no caracteres
    chunk_overlap=50   # 50 tokens de solapamiento
)

# Fragmentamos
documentos_fragmentados = text_splitter.split_documents(documentos_oci)

# Verificación
print(f"✅ Fragmentos generados: {len(documentos_fragmentados)}")
# Out:
# ✅ Fragmentos generados: 12

# %% [markdown]
# ## 3 - Vectorización (Embedings)

# %%
# Inicialización del modelo de Embeddings
# Creación e indexación en base de datos vectorial local (ej. FAISS o Chroma)

from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-small')
model = AutoModel.from_pretrained('intfloat/multilingual-e5-small')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from transformers import AutoTokenizer

# 1. Cargamos el tokenizer del modelo
model_id = 'intfloat/multilingual-e5-small'
tokenizer = AutoTokenizer.from_pretrained(model_id)

# 2. Configuramos el splitter para que respete el límite de tokens (512)
# Usamos un chunk_size menor (ej. 450) para dejar margen al overlap y evitar el error
text_splitter = RecursiveCharacterTextSplitter.from_huggingface_tokenizer(
    tokenizer=tokenizer,
    chunk_size=450,
    chunk_overlap=50
)

# 3. Fragmentamos
hf_fragmentos = text_splitter.split_documents(documentos_oci)

print(f"✅ Fragmentación completada.")
print(f"Total de fragmentos generados: {len(hf_fragmentos)}")
# Out:
# ✅ Fragmentación completada.
# Total de fragmentos generados: 11

# %%
hf_splitter = CharacterTextSplitter.from_huggingface_tokenizer(
    tokenizer=tokenizer,
    chunk_size=512,
    chunk_overlap=50
)

# %%
hf_fragmentos = hf_splitter.split_documents(documentos_oci)
len(hf_fragmentos)
# Out:
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (546 > 512). Running this sequence through the model will result in indexing errors
# 7

# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain_huggingface import HuggingFaceEmbeddings

# 1. Cargamos el modelo local (eficiente para fragmentar sin llamadas a API)
hf_emb_model = HuggingFaceEmbeddings(model_name='intfloat/multilingual-e5-small')

# 2. Configuramos el SemanticChunker
# breakpoint_threshold_type: "percentile" suele ser el más estable para textos técnicos
semantic_hf_splitter = SemanticChunker(
    hf_emb_model,
    breakpoint_threshold_type="percentile"
)

# 3. Fragmentación semántica
print("⏳ Fragmentando semánticamente (esto puede tomar un momento)...")
semantic_hf_chunks = semantic_hf_splitter.split_documents(documentos_oci)

print(f"✅ Fragmentación semántica completada: {len(semantic_hf_chunks)} fragmentos.")
# Out:
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/498k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# ⏳ Fragmentando semánticamente (esto puede tomar un momento)...
# ✅ Fragmentación semántica completada: 15 fragmentos.

# %% [markdown]
# ## 4 -Recuperacion RAG

# %% [markdown]
# ### 1. Transformación de la pregunta en embedding

# %%
# Función de búsqueda semántica
# Implementación de filtros por metadatos (ej. filtrar solo por "Pozo PCP")
# Componente de Reranking (opcional, para mejorar precisión)

# %% [markdown]
# ###  2. Búsqueda semántica en la base de datos vectorial

# %% [markdown]
# ### 3. Filtrado por metadados

# %% [markdown]
# ### 4. Reclasificación (Reranking)

# %% [markdown]
# ### 5. Ensamblaje del contexto

# %% [markdown]
# ## 5 - Producción y validación de respuestas

# %%
# Prompt Engineering (Definiendo el rol del Agente OCI y la regla "Human-in-the-loop")
# Lógica de fallback: "No cuento con esa información en los manuales actuales..."
# Función final de la aplicación

# %% [markdown]
# ### 1. Generación de la respuesta

# %% [markdown]
# ### 2. Citación de la fuente

# %% [markdown]
# ### 3. Validación y control de alucinación

# %% [markdown]
# ### 4. Fallback (alternativa) cuando no hay respuesta

# %% [markdown]
# ### 5. Formato final
